# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('USvideos.csv')

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

numerical_cols = ['views', 'likes', 'dislikes', 'comment_count']
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(data[col], kde=True, bins=30, color='blue')
    plt.title(f"Distribution of {col}")
    plt.show()

for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=data[col], color='cyan')
    plt.title(f"Boxplot of {col}")
    plt.show()

plt.figure(figsize=(10, 8))
correlation_matrix = data[numerical_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(x=data['category_id'], palette="viridis")
plt.title("Countplot of Category ID")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Jarvis\AppData\Local\Temp\ipykernel_21216\3281448703.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['category_id'], palette="viridis")
